# %%
from pydantic import BaseModel, EmailStr, AnyUrl, Field
from typing import List, Dict, Optional, Annotated

# %%
pip install pydantic
# Out:
# Requirement already satisfied: pydantic in /Users/aditigupta/anaconda3/lib/python3.11/site-packages (2.12.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/aditigupta/anaconda3/lib/python3.11/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/aditigupta/anaconda3/lib/python3.11/site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/aditigupta/anaconda3/lib/python3.11/site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/aditigupta/anaconda3/lib/python3.11/site-packages (from pydantic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install 'pydantic[email]'
# Out:
# Requirement already satisfied: pydantic[email] in /opt/anaconda3/lib/python3.12/site-packages (2.12.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic[email]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic[email]) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic[email]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic[email]) (0.4.2)
# Requirement already satisfied: email-validator>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic[email]) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from email-validator>=2.0.0->pydantic[email]) (2.8.0)
# Requirement already satisfied: idna>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from email-validator>=2.0.0->pydantic[email]) (3.7)
#
# [notice] A new release of pip is available: 26.0 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install email-validator
# Out:
# Requirement already satisfied: email-validator in /Users/aditigupta/anaconda3/lib/python3.11/site-packages (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in /Users/aditigupta/anaconda3/lib/python3.11/site-packages (from email-validator) (2.8.0)
# Requirement already satisfied: idna>=2.0.0 in /Users/aditigupta/anaconda3/lib/python3.11/site-packages (from email-validator) (3.4)

# %%
# 1. Define the model
class Patient(BaseModel):
    name: Annotated[str, Field(max_length=50, title = 'Name of the patient', 
                               description='Give the name of the patient in less than 50 char',
                              examples=['Aditi', ['Reeva']])]  #str = Field(max_length=50)
    email: EmailStr
    linkedinUrl : AnyUrl
    age :int = Field(gt=0,lt=110)
    weight : Annotated[float, Field(gt=0,strict=True)]  #float= Field(gt=0)
                        #strict here is strictly accepting only float values 
    married : Annotated[bool, Field(default=None, description='Is the patient married or not')]   #bool = False
    allergies : Annotated[Optional[List[str]],Field(default=None,max_length=5)]  #Optional[List[str]] = Field(max_length=5)  #None
    contact_details : Dict[str,str]

# %%
# 2. Define the function — it RECEIVES a patient, doesn't create one
def insert_patient_data(patient: Patient):
    print(patient.name)
    print(patient.email)
    print(patient.linkedinUrl)
    print(patient.age)
    print(patient.weight)
    print(patient.allergies)
    print(patient.married)
    print("inserted")

# %%
# 3. Create patient1  
patient_info = {'name' : 'AditiAditiAditiAditiAditiAditiAditiAditiAditiAditi', 
                'email' : 'aditi.gup30@gmail.com',
                'linkedinUrl' : 'http://www.linkedin.com',
                'age': 30, 
                'weight':75.3, 
                #'married' : True,
                'allergies':['pollen','dust','abc','xyz'],
                'contact_details':{'email':'aditi.gup30@gmail.com','phone' :'8482280198'}}
patient1 = Patient(**patient_info)

# %%
insert_patient_data(patient1)
# Out:
# AditiAditiAditiAditiAditiAditiAditiAditiAditiAditi
# aditi.gup30@gmail.com
# http://www.linkedin.com/
# 30
# 75.3
# ['pollen', 'dust', 'abc', 'xyz']
# None
# inserted
